# %%
import pandas as pd

# %%
df = pd.read_excel('sachin_1485096136665.xlsx')

# %%
df.head()
# Out:
#   batting_score wickets runs_conceded catches stumps     opposition  \
# 0           0.0       -             -     0.0    0.0     v Pakistan
# 1           0.0       -             -     0.0    0.0  v New Zealand
# 2          36.0       -             -     0.0    0.0  v New Zealand
# 3          10.0       -             -     1.0    0.0    v Sri Lanka
# 4          20.0       -             -     0.0    0.0     v Pakistan
#
#        ground       date match_result result_margin  toss batting_innings
# 0  Gujranwala 1989-12-18         lost        7 runs   won             2nd
# 1     Dunedin 1990-03-01         lost      108 runs   won             2nd
# 2  Wellington 1990-03-06          won        1 runs   won             1st
# 3     Sharjah 1990-04-25         lost     3 wickets  lost             1st
# 4     Sharjah 1990-04-27         lost       26 runs   won             2nd

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
