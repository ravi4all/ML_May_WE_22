# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = np.random.rand(400,1) * 5

# %%
y = X ** np.random.randint(1,4)

# %%
plt.scatter(X, y)
plt.show()

# %%
regression = LinearRegression()
regression.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, 'r')
plt.show()

# %%
np.sqrt(mean_squared_error(y, y_pred))
# Out:
# 14.35443334318369

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures()
poly_x = poly.fit_transform(X)
poly.fit(poly_x, y)
# Out:
# PolynomialFeatures()

# %%
# poly_x

# %%
poly_regression = LinearRegression()

# %%
poly_regression.fit(poly_x, y)
# Out:
# LinearRegression()

# %%
y_pred_poly = poly_regression.predict(poly_x)

# %%
np.sqrt(mean_squared_error(y_pred_poly, y))
# Out:
# 2.4619220600252105

# %%
plt.scatter(X, y)
plt.plot(X, y_pred_poly, 'r')
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y, y_pred)
# Out:
# 0.8309033177069252

# %%
r2_score(y, y_pred_poly)
# Out:
# 0.9950259335759342
