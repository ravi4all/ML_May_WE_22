# %%
import pandas as pd
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score
from matplotlib.colors import ListedColormap

# %%
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples=500, centers=2, cluster_std=1.9)

# %%
X.shape
# Out:
# (500, 2)

# %%
y.shape
# Out:
# (500,)

# %%
X[:5]
# Out:
# array([[ 2.96313899, -4.10454807],
#        [-6.50504686, -1.02891479],
#        [ 2.01364629, -6.93175611],
#        [-7.80805295, -2.57619279],
#        [ 1.63677622, -7.0745298 ]])

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
def classfier(X,y,C=1.0):
    plt.scatter(X[:,0], X[:,1], c=y)
    clf = SVC(kernel='linear', C=C)
    clf = clf.fit(X,y)
    
    #gca - get current axes
    ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    x1 = np.linspace(xlim[0], xlim[1], 200)
    x2 = np.linspace(ylim[0], ylim[1], 200)
    
    xx, yy = np.meshgrid(x1, x2)
    x = np.vstack([xx.flatten(), yy.flatten()]).T
    z = clf.decision_function(x).reshape(xx.shape)
    
    ax.contour(xx,yy,z, colors='k', levels=[-1,0,1], linestyles=['--','-','--'])
    ax.scatter(clf.support_vectors_[:,0], clf.support_vectors_[:,1], s=100)
    plt.show()
    
    return clf

# %%
classfier(X,y, C=1.0)
# Out:
# SVC(kernel='linear')
