# %%
import pandas as pd
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score
from matplotlib.colors import ListedColormap

# %%
from sklearn.datasets import make_moons

# %%
X,y = make_moons(n_samples=500, noise=0.1)

# %%
X.shape
# Out:
# (500, 2)

# %%
y.shape
# Out:
# (500,)

# %%
X[:5]
# Out:
# array([[ 0.64306509,  0.48704201],
#        [ 0.64192805,  0.37131953],
#        [ 0.39599129,  0.70714317],
#        [-0.80200286,  0.60994479],
#        [ 1.87892015,  0.09742295]])

# %%
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
def classfier(X,y,C=1.0):
    plt.scatter(X[:,0], X[:,1], c=y)
    #rbf - radial based function
    clf = SVC(kernel='rbf', C=C)
    clf = clf.fit(X,y)
    
    #gca - get current axes
    ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    
    x1 = np.linspace(xlim[0], xlim[1], 200)
    x2 = np.linspace(ylim[0], ylim[1], 200)
    
    xx, yy = np.meshgrid(x1, x2)
    x = np.vstack([xx.flatten(), yy.flatten()]).T
    z = clf.decision_function(x).reshape(xx.shape)
    
    ax.contour(xx,yy,z, colors='k', levels=[-1,0,1], linestyles=['--','-','--'])
    ax.scatter(clf.support_vectors_[:,0], clf.support_vectors_[:,1], s=100)
    plt.show()
    
    return clf

# %%
classfier(X,y, C=0.5)
# Out:
# SVC(C=0.5)

# %%
classfier(X,y, C=0.9)
# Out:
# SVC(C=0.9)

# %%
classfier(X,y, C=1.0)
# Out:
# SVC()

# %%
classfier(X,y, C=5)
# Out:
# SVC(C=5)
